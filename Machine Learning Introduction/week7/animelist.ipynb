# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
base = pd.read_csv('AnimeList.csv')

# %%
base.head()
# Out:
#    anime_id                title              title_english title_japanese  \
# 0     11013        Inu x Boku SS  Inu X Boku Secret Service         妖狐×僕SS
# 1      2104     Seto no Hanayome      My Bride is a Mermaid          瀬戸の花嫁
# 2      5262   Shugo Chara!! Doki         Shugo Chara!! Doki    しゅごキャラ！！どきっ
# 3       721        Princess Tutu              Princess Tutu      プリンセスチュチュ
# 4     12365  Bakuman. 3rd Season                   Bakuman.          バクマン。
#
#                                   title_synonyms  \
# 0                                Youko x Boku SS
# 1                           The Inland Sea Bride
# 2  Shugo Chara Ninenme, Shugo Chara! Second Year
# 3                                            NaN
# 4                               Bakuman Season 3
#
#                                            image_url type    source  episodes  \
# 0  https://myanimelist.cdn-dena.com/images/anime/...   TV     Manga        12
# ...

# %%
pd.set_option('display.max_columns', 100)

# %%
base.head()
# Out:
#    anime_id                title              title_english title_japanese  \
# 0     11013        Inu x Boku SS  Inu X Boku Secret Service         妖狐×僕SS
# 1      2104     Seto no Hanayome      My Bride is a Mermaid          瀬戸の花嫁
# 2      5262   Shugo Chara!! Doki         Shugo Chara!! Doki    しゅごキャラ！！どきっ
# 3       721        Princess Tutu              Princess Tutu      プリンセスチュチュ
# 4     12365  Bakuman. 3rd Season                   Bakuman.          バクマン。
#
#                                   title_synonyms  \
# 0                                Youko x Boku SS
# 1                           The Inland Sea Bride
# 2  Shugo Chara Ninenme, Shugo Chara! Second Year
# 3                                            NaN
# 4                               Bakuman Season 3
#
#                                            image_url type    source  episodes  \
# 0  https://myanimelist.cdn-dena.com/images/anime/...   TV     Manga        12
# ...

# %%
base.drop(['title_english', 'title_japanese', 'title_synonyms', 'image_url', 'aired', 'related', 'opening_theme', 'ending_theme'], axis=1)
# Out:
#        anime_id                                  title     type    source  \
# 0         11013                          Inu x Boku SS       TV     Manga
# 1          2104                       Seto no Hanayome       TV     Manga
# 2          5262                     Shugo Chara!! Doki       TV     Manga
# 3           721                          Princess Tutu       TV  Original
# 4         12365                    Bakuman. 3rd Season       TV     Manga
# ...         ...                                    ...      ...       ...
# 14473     26089             Gutchonpa Omoshiro Hanashi       TV   Unknown
# 14474     21525                   Geba Geba Shou Time!      OVA   Unknown
# 14475     37897            Godzilla: Hoshi wo Kuu Mono    Movie     Other
# 14476     34193  Nippon Mukashibanashi: Sannen Netarou      OVA     Other
# 14477     37908             Senjou no Valkyria Special  Special   Unknown
#
#        episodes           status  airing                  aired_string  \
# ...

# %%
base.isnull().sum()
# Out:
# anime_id              0
# title                 0
# title_english      8754
# title_japanese       35
# title_synonyms     5541
# image_url            96
# type                  0
# source                0
# episodes              0
# status                0
# airing                0
# aired_string          0
# aired                 0
# duration              0
# rating                0
# score                 0
# scored_by             0
# rank               1574
# popularity            0
# members               0
# favorites             0
# background        13421
# premiered         10382
# broadcast         10207
# related               0
# producer           6190
# licensor          11105
# studio             5934
# genre                64
# opening_theme         0
# ending_theme          0
# dtype: int64

# %% [markdown]
# Não há colunas com variáveis numéricas utilizadas para cálculos estatísticos que estejam com dados faltantes

# %%
base.describe()
# Out:
#            anime_id      episodes         score     scored_by          rank  \
# count  14478.000000  14478.000000  14478.000000  1.447800e+04  12904.000000
# mean   17377.229866     11.308399      6.142482  1.146003e+04   6439.065406
# std    13165.315011     43.443451      1.463981  4.310519e+04   3720.227608
# min        1.000000      0.000000      0.000000  0.000000e+00      0.000000
# 25%     4389.250000      1.000000      5.550000  4.600000e+01   3216.250000
# 50%    15135.000000      1.000000      6.370000  5.010000e+02   6441.500000
# 75%    31146.500000     12.000000      7.060000  3.941500e+03   9664.000000
# max    37916.000000   1818.000000     10.000000  1.009477e+06  12919.000000
#
#          popularity       members      favorites
# count  14478.000000  1.447800e+04   14478.000000
# mean    7220.259566  2.296640e+04     311.649606
# std     4170.080564  7.498136e+04    2615.554211
# min        0.000000  0.000000e+00       0.000000
# ...

# %%
import plotly.express as px

tips = px.data.tips()
fig = px.histogram(base, y="type", orientation="h", title='Stream').update_xaxes(categoryorder='total ascending')
fig.show()

# %%
tipsSource = px.data.tips()
figSource = px.histogram(base, y="source", orientation="h", title='Adaptações').update_xaxes(categoryorder='total ascending')

figSource.show()

# %%
tipsGenre = px.data.tips()
figGenre= px.histogram(base, y=base.genre, orientation="h", title='Gêneros').update_xaxes(categoryorder='total ascending')

figGenre.show()

# %%
base.genre.unique()
# Out:
# array(['Comedy, Supernatural, Romance, Shounen',
#        'Comedy, Parody, Romance, School, Shounen',
#        'Comedy, Magic, School, Shoujo', ..., 'Music, Romance, Seinen',
#        'Historical, Kids, Sci-Fi', 'Game, Magic'], dtype=object)

# %%
base.value_counts(base.genre)
# Out:
# genre
# Hentai                                                       868
# Comedy                                                       590
# Music                                                        533
# Kids                                                         285
# Slice of Life                                                166
#                                                             ...
# Adventure, Sci-Fi, Shounen, Space                              1
# Military, Sci-Fi, Adventure, Drama, Romance, Mecha             1
# Military, Sci-Fi, Adventure, Space, Drama, Romance, Mecha      1
# Adventure, Samurai, Sci-Fi, Shounen                            1
# Action, Supernatural, Shounen                                  1
# Length: 4544, dtype: int64
